# %%
import sys
print(sys.path)
sys.path.append('/Users/zoe.yan/Desktop/echelon/echelon-project')
# Out:
# ['/opt/homebrew/Cellar/python@3.13/3.13.4/Frameworks/Python.framework/Versions/3.13/lib/python313.zip', '/opt/homebrew/Cellar/python@3.13/3.13.4/Frameworks/Python.framework/Versions/3.13/lib/python3.13', '/opt/homebrew/Cellar/python@3.13/3.13.4/Frameworks/Python.framework/Versions/3.13/lib/python3.13/lib-dynload', '', '/Users/zoe.yan/Desktop/echelon/echelon-project/venv/lib/python3.13/site-packages']

# %%
from src.agent.master_agent import MasterAgent
from agents.extensions.visualization import draw_graph
draw_graph(MasterAgent().agent)
# Out:
# 🤖 MasterAgent | INFO | STEP: Database schema file not found | Details: {
#   "schema_path": "data/database_schema.json"
# }
# 🤖 MasterAgent | INFO | STEP: Initializing MasterAgent | Details: {
#   "model": "gpt-5",
#   "db_path": "data/forms.sqlite",
#   "schema_loaded": false,
#   "verbose_logging": true
# }
# 🤖 AskClarificationAgent | INFO | STEP: Initializing AskClarificationAgent | Details: {
#   "model": "gpt-5"
# }
# 🤖 AskClarificationAgent | INFO | STEP: AskClarificationAgent initialized successfully
# 🤖 ValidatorAgent | INFO | STEP: Initializing ValidatorAgent | Details: {
#   "model": "gpt-5",
#   "db_path": "data/forms.sqlite"
# }
# 🤖 ValidatorAgent | INFO | STEP: Created 9 validation tools
# 🤖 ValidatorAgent | INFO | STEP: ValidatorAgent initialized successfully
# 🤖 ContextMemory | INFO | STEP: Initializing ContextMemory | Details: {
#   "session_id": "b46dbe3e-1e99-4ddc-a221-8341c475b3c1",
#   "created_at": "2025-08-15T09:22:05.156586"
# }
# ...
